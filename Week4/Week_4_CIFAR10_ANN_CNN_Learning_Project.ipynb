# %% [markdown]
# # 📘 CIFAR-10 Image Classification Learning Project
# ## Build and Compare **ANN vs CNN** on CIFAR-10
#
# This notebook is designed for **students and beginners** to learn:
# - How image classification works
# - Why **CNN performs better than ANN**
# - How architecture impacts performance
# - How training strategies improve results
#
# 🎯 **Learning Goal:** Understand the complete DL pipeline by **reading the markdown + running the ready code**.

# %% [markdown]
# # 🧠 Problem Statement
# Build an image classification model on the **CIFAR-10 dataset** using:
#
# 1. **Artificial Neural Network (ANN)**
# 2. **Convolutional Neural Network (CNN)**
#
# Then compare:
# - Accuracy
# - Loss curves
# - Generalization
# - Training strategies (dropout, batch norm, augmentation)
#
# ---
# ### 📦 CIFAR-10 Classes
# Airplane, Automobile, Bird, Cat, Deer, Dog, Frog, Horse, Ship, Truck

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.20.0

# %% [markdown]
# # 📥 Load Dataset
# We use **CIFAR-10**, which contains **60,000 color images of size 32×32×3**.
# - 50,000 training images
# - 10,000 test images

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

print("Train shape:", x_train.shape)
print("Test shape:", x_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 221s 1us/step
# Train shape: (50000, 32, 32, 3)
# Test shape: (10000, 32, 32, 3)

# %% [markdown]
# ## 🖼️ Visualize Sample Images

# %%
plt.figure(figsize=(10,5))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(x_train[i])
    plt.title(class_names[y_train[i][0]])
    plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 🧹 Preprocessing
# We normalize pixel values from **0–255 → 0–1** so training becomes stable.

# %%
x_train_norm = x_train / 255.0
x_test_norm = x_test / 255.0

x_train_flat = x_train_norm.reshape(len(x_train_norm), -1)
x_test_flat = x_test_norm.reshape(len(x_test_norm), -1)

# %% [markdown]
# # 🔹 Part 1: ANN Model
# ANN treats images as **flat vectors**, so it cannot preserve spatial features.
# This helps students understand **why CNN is better for images**.

# %%
ann_model = models.Sequential([
    layers.Dense(512, activation='relu', input_shape=(3072,)),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.Dense(10, activation='softmax')
])

ann_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

ann_history = ann_model.fit(
    x_train_flat, y_train,
    epochs=10,
    validation_split=0.1,
    batch_size=64
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 24s 32ms/step - accuracy: 0.2650 - loss: 1.9995 - val_accuracy: 0.3378 - val_loss: 1.8410
# Epoch 2/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.3220 - loss: 1.8544 - val_accuracy: 0.3528 - val_loss: 1.8085
# Epoch 3/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 27ms/step - accuracy: 0.3385 - loss: 1.8088 - val_accuracy: 0.3894 - val_loss: 1.7509
# Epoch 4/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.3477 - loss: 1.7873 - val_accuracy: 0.3664 - val_loss: 1.7494
# Epoch 5/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 27ms/step - accuracy: 0.3588 - loss: 1.7553 - val_accuracy: 0.3944 - val_loss: 1.6900
# Epoch 6/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.3675 - loss: 1.7412 - val_accuracy: 0.4116 - val_loss: 1.6786
# Epoch 7/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 27ms/step - accuracy: 0.3731 - loss: 1.7184 - val_accuracy: 0.4124 - val_loss: 1.6699
# Epoch 8/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.3772 - loss: 1.7117 - val_accuracy: 0.4064 - val_loss: 1.6638
# Epoch 9/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 27ms/step - accuracy: 0.3842 - loss: 1.6968 - val_accuracy: 0.3954 - val_loss: 1.6863
# Epoch 10/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.3825 - loss: 1.6971 - val_accuracy: 0.4214 - val_loss: 1.6601

# %%
ann_test_loss, ann_test_acc = ann_model.evaluate(x_test_flat, y_test)
print("ANN Test Accuracy:", ann_test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.4209 - loss: 1.6504
# ANN Test Accuracy: 0.42089998722076416

# %% [markdown]
# # 🔹 Part 2: CNN Model
# CNN preserves **spatial relationships** using:
# - Convolution layers
# - Pooling
# - Feature extraction
# - Hierarchical learning
#
# This is why CNN performs much better for image tasks.

# %%
cnn_model = models.Sequential([
    layers.Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, (3,3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(128, (3,3), activation='relu'),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(10, activation='softmax')
])

cnn_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

cnn_history = cnn_model.fit(
    x_train_norm, y_train,
    epochs=10,
    validation_split=0.1,
    batch_size=64
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 90s 124ms/step - accuracy: 0.4636 - loss: 1.5068 - val_accuracy: 0.4996 - val_loss: 1.4387
# Epoch 2/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 139s 120ms/step - accuracy: 0.6061 - loss: 1.1285 - val_accuracy: 0.6324 - val_loss: 1.0646
# Epoch 3/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 142s 120ms/step - accuracy: 0.6670 - loss: 0.9555 - val_accuracy: 0.5946 - val_loss: 1.1989
# Epoch 4/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 88s 124ms/step - accuracy: 0.7065 - loss: 0.8385 - val_accuracy: 0.6612 - val_loss: 0.9825
# Epoch 5/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 139s 120ms/step - accuracy: 0.7386 - loss: 0.7456 - val_accuracy: 0.6550 - val_loss: 0.9891
# Epoch 6/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 86s 122ms/step - accuracy: 0.7659 - loss: 0.6673 - val_accuracy: 0.6992 - val_loss: 0.8886
# Epoch 7/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 85s 121ms/step - accuracy: 0.7894 - loss: 0.5944 - val_accuracy: 0.6962 - val_loss: 0.9440
# Epoch 8/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 141s 120ms/step - accuracy: 0.8099 - loss: 0.5374 - val_accuracy: 0.7258 - val_loss: 0.8331
# Epoch 9/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 143s 122ms/step - accuracy: 0.8288 - loss: 0.4814 - val_accuracy: 0.6934 - val_loss: 0.9708
# Epoch 10/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 141s 120ms/step - accuracy: 0.8427 - loss: 0.4410 - val_accuracy: 0.7302 - val_loss: 0.8906

# %%
cnn_test_loss, cnn_test_acc = cnn_model.evaluate(x_test_norm, y_test)
print("CNN Test Accuracy:", cnn_test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.7179 - loss: 0.9660
# CNN Test Accuracy: 0.7178999781608582

# %% [markdown]
# ## 📈 Compare Learning Curves

# %%
plt.figure(figsize=(10,4))
plt.plot(ann_history.history['val_accuracy'], label='ANN Val Acc')
plt.plot(cnn_history.history['val_accuracy'], label='CNN Val Acc')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("ANN vs CNN Validation Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# # 🚀 Training Strategy Upgrade: Data Augmentation
# This strategy improves generalization by generating transformed images.

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1)
])

aug_cnn_model = models.Sequential([
    data_augmentation,
    layers.Conv2D(32, 3, activation='relu', input_shape=(32,32,3)),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(10, activation='softmax')
])

aug_cnn_model.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])

# Suggested optional run:
# aug_history = aug_cnn_model.fit(x_train_norm, y_train, epochs=10, validation_split=0.1)

# %% [markdown]
# # 📊 Final Comparison Table

# %%
comparison = pd.DataFrame({
    "Model": ["ANN", "CNN"],
    "Test Accuracy": [ann_test_acc, cnn_test_acc]
})
comparison
# Out:
#   Model  Test Accuracy
# 0   ANN         0.4209
# 1   CNN         0.7179

# %% [markdown]
# # 🎓 Student Learning Tasks
# Try these tasks after understanding the notebook:
#
# ### ✅ Beginner Tasks
# 1. Increase ANN layers and observe performance
# 2. Change CNN filters from 32→64→128
# 3. Increase epochs to 20
# 4. Add **EarlyStopping**
# 5. Add **data augmentation training**

# %% [markdown]
# # ✅ Conclusion
# - **ANN works**, but ignores image structure
# - **CNN extracts spatial features**, so it performs significantly better
# - **Training strategies** like dropout, batch norm, and augmentation improve results
# - This project builds strong fundamentals for **computer vision interviews and deep learning projects**
